# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 79.4 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %%
import pulp

# Define the items with their value ($) and volume (cubic feet)
items = [
    {"name": "Bedroom set", "value": 600, "volume": 800},
    {"name": "Dining room set", "value": 480, "volume": 600},
    {"name": "Gaming computer", "value": 140, "volume": 300},
    {"name": "Sofa", "value": 310, "volume": 400},
    {"name": "TV", "value": 100, "volume": 200}
]

# Create a list of item names
item_names = [item["name"] for item in items]

# Define the volume limit of the truck
volume_limit = 1100

# Define the problem
prob = pulp.LpProblem("Moving_Truck_Optimization", pulp.LpMaximize)

# Define decision variables
decision_vars = pulp.LpVariable.dicts("Item", item_names, lowBound=0, upBound=1, cat="Integer")

# Define the objective function: maximize total value
prob += pulp.lpSum([item["value"] * decision_vars[item["name"]] for item in items])

# Define the constraint: total volume must be within the truck's limit
prob += pulp.lpSum([item["volume"] * decision_vars[item["name"]] for item in items]) <= volume_limit

# Solve the problem
prob.solve()

# Print the results
print("Best combination of items to move:")
for item in items:
    if pulp.value(decision_vars[item["name"]]) == 1:
        print(f"{item['name']} - Value: ${item['value']}, Volume: {item['volume']} cubic feet")
total_value = sum(item["value"] for item in items if pulp.value(decision_vars[item["name"]]) == 1)
total_volume = sum(item["volume"] for item in items if pulp.value(decision_vars[item["name"]]) == 1)
print(f"Total value: ${total_value}")
print(f"Total volume: {total_volume} cubic feet")
# Out:
# Best combination of items to move:
# Dining room set - Value: $480, Volume: 600 cubic feet
# Sofa - Value: $310, Volume: 400 cubic feet
# Total value: $790
# Total volume: 1000 cubic feet

# %%
# prompt: grab all file names from /content/drive/MyDrive/MSDS422 - Group 1/Final Project/Data that are xlsx

import os
import pandas as pd

data_dir = '/content/drive/MyDrive/MSDS422 - Group 1/Final Project/Data'

filenames = []
for filename in os.listdir(data_dir):
    if filename.endswith(".xlsx"):
        filenames.append(filename)

if len(filenames) > 0:
    print("File Names Found:")
    for filename in filenames:
      print(filename)


print()
# Check if the directory exists
if os.path.exists(data_directory):
  filenames = [f for f in os.listdir(data_directory) if os.path.isfile(os.path.join(data_directory, f))]
  print("File Names and Sheet Tabs in the Directory:")
  for filename in filenames:
    try:
      # Attempt to open the file as an Excel file
      file_path = os.path.join(data_directory, filename)
      excel_file = pd.ExcelFile(file_path)
      sheet_names = excel_file.sheet_names
      print(f"{filename}: {sheet_names}")

    except FileNotFoundError:
      print(f"Error: File '{filename}' not found.")
    except Exception as e:  # Catch other potential errors (e.g., not an Excel file)
      print(f"Error processing '{filename}': {e}")

else:
  print(f"Error: Directory '{data_directory}' not found.")
# Out:
# File Names Found:
# ghgp_data_2013.xlsx
# ghgp_data_2018.xlsx
# ghgp_data_2017.xlsx
# ghgp_data_2016.xlsx
# ghgp_data_2012.xlsx
# ghgp_data_2011.xlsx
# ghgp_data_2010.xlsx
# ghgp_data_2019.xlsx
# ghgp_data_2015.xlsx
# ghgp_data_2014.xlsx
# ghgp_data_by_year_2023.xlsx
# ghgp_data_2022.xlsx
# ghgp_data_2021.xlsx
# ghgp_data_2023.xlsx
# ghgp_data_2020.xlsx
#
# File Names and Sheet Tabs in the Directory:
# ghgp_data_2013.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2018.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2017.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2016.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2012.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2011.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2010.xlsx: ['Direct Emitters', 'Suppliers', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2019.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2015.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2014.xlsx: ['Direct Emitters', 'Onshore Oil & Gas Prod.', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Industry Type', 'FAQs about this Data']
# ghgp_data_by_year_2023.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2022.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2021.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2023.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# ghgp_data_2020.xlsx: ['Direct Point Emitters', 'Onshore Oil & Gas Prod.', 'Gathering & Boosting', 'Transmission Pipelines', 'LDC - Direct Emissions', 'SF6 from Elec. Equip.', 'Suppliers', 'CO2 Injection', 'Geologic Sequestration of CO2', 'Industry Type', 'FAQs about this Data']
# Error processing 'Untitled0.ipynb': Excel file format cannot be determined, you must specify an engine manually.

# %%
# prompt: Output A4 for cell 1 on the first sheet of each file

from google.colab import drive
import os
import pandas as pd
drive.mount('/content/drive')

data_dir = '/content/drive/MyDrive/MSDS422 - Group 1/Final Project/Data'

filenames = []
for filename in os.listdir(data_dir):
    if filename.endswith(".xlsx"):
        filenames.append(filename)

if len(filenames) > 0:
    print("File Names Found:")
    for filename in filenames:
      print(filename)
      try:
        file_path = os.path.join(data_dir, filename)
        excel_file = pd.ExcelFile(file_path)
        for sheet_name in excel_file.sheet_names:
          df = pd.read_excel(file_path, sheet_name=sheet_name, header=None) # header=None to avoid issues with headers
          if not df.empty and 0 in df.index and 0 in df.columns: #check if the cell exists
            print(f"Value in cell A4 ({sheet_name}): {df.iloc[0,0]}") # Access using .iloc to avoid index errors
          else:
              print(f"Cell A1 not found or sheet '{sheet_name}' in file '{filename}' is empty")
      except Exception as e:
        print(f"Error processing {filename}: {e}")
else:
    print("No .xlsx files found in the specified directory.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File Names Found:
# ghgp_data_2013.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2013
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2018.xlsx
# Value in cell A4 (Direct Point Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Gathering & Boosting): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Transmission Pipelines): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Geologic Sequestration of CO2): Summary data collected by the Greenhouse Gas Reporting Program for 2018
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2017.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Gathering & Boosting): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Transmission Pipelines): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Geologic Sequestration of CO2): Summary data collected by the Greenhouse Gas Reporting Program for 2017
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2016.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Gathering & Boosting): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Transmission Pipelines): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Geologic Sequestration of CO2): Summary data collected by the Greenhouse Gas Reporting Program for 2016
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2012.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2012
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2011.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2011
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2010.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2010
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2010
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2019.xlsx
# Value in cell A4 (Direct Point Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Gathering & Boosting): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Transmission Pipelines): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Geologic Sequestration of CO2): Summary data collected by the Greenhouse Gas Reporting Program for 2019
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2015.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2015
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2014.xlsx
# Value in cell A4 (Direct Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (Onshore Oil & Gas Prod.): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (LDC - Direct Emissions): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (SF6 from Elec. Equip.): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (Suppliers): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (CO2 Injection): Summary data collected by the Greenhouse Gas Reporting Program for 2014
# Value in cell A4 (Industry Type): nan
# Value in cell A4 (FAQs about this Data): 1. What is a Facility ID?
# ghgp_data_2022.xlsx
# Value in cell A4 (Direct Point Emitters): Summary data collected by the Greenhouse Gas Reporting Program for 2022
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1ab325c12d71> in <cell line: 0>()
#      21         excel_file = pd.ExcelFile(file_path)
#      22         for sheet_name in excel_file.sheet_names:
# ---> 23           df = pd.read_excel(file_path, sheet_name=sheet_name, header=None) # header=None to avoid issues with headers
#      24           if not df.empty and 0 in df.index and 0 in df.columns: #check if the cell exists
#      25             print(f"Value in cell A4 ({sheet_name}): {df.iloc[0,0]}") # Access using .iloc to avoid index errors
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1565         self.storage_options = storage_options
#    1566
# -> 1567         self._reader = self._engines[engine](
#    1568             self._io,
#    1569             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_openpyxl.py in __init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     551         """
#     552         import_optional_dependency("openpyxl")
# --> 553         super().__init__(
#     554             filepath_or_buffer,
#     555             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     571             self.handles.handle.seek(0)
#     572             try:
# --> 573                 self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     574             except Exception:
#     575                 self.close()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_openpyxl.py in load_workbook(self, filepath_or_buffer, engine_kwargs)
#     570         default_kwargs = {"read_only": True, "data_only": True, "keep_links": False}
#     571
# --> 572         return load_workbook(
#     573             filepath_or_buffer,
#     574             **(default_kwargs | engine_kwargs),
#
# /usr/local/lib/python3.11/dist-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
# --> 348     reader.read()
#     349     return reader.wb
#
# /usr/local/lib/python3.11/dist-packages/openpyxl/reader/excel.py in read(self)
#     289             self.read_manifest()
#     290             action = "read strings"
# --> 291             self.read_strings()
#     292             action = "read workbook"
#     293             self.read_workbook()
#
# /usr/local/lib/python3.11/dist-packages/openpyxl/reader/excel.py in read_strings(self)
#     144         if ct is not None:
#     145             strings_path = ct.PartName[1:]
# --> 146             with self.archive.open(strings_path,) as src:
#     147                 self.shared_strings = reader(src)
#     148
#
# /usr/lib/python3.11/zipfile.py in close(self)
#    1073         return data
#    1074
# -> 1075     def close(self):
#    1076         try:
#    1077             if self._close_fileobj:
#
# KeyboardInterrupt:
